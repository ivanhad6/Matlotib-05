# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.4.3
# 1.20.3

# %%
#FUNGSI PLOTTING

def gambar_barplot():
  data1 = [25,85,75,40,60]
  data2 = [40,35,20,55,10]
  kategori = ['A', 'B', 'C', 'D', 'E']

  x = np.arange(len(kategori))
  width = 0.35 #semakin kecil widthnya, semakin tipis juga bar yang akan dihasilkan.
  
  plt.bar(x-width/2,data1,width,label='Data 1')
  plt.bar(x+width/2,data2,width,label='Data 2')

  plt.xticks(x, kategori) #Untuk menampilkan isi dari kategori yang kita inginkan dan bukan berisi indeks.
  plt.grid(linestyle='--', #mengatur tipe garis
         linewidth=1, #mengatur tingkat ketebalan garis
         axis='y', #pilihan: x,y,both. Karena disini axis ='y', maka garisnya akan berasosiasi dengan sumbu y
         alpha=0.75) #Untuk mengatur tingkat transparansi garis

  plt.xlabel('Kategori')
  plt.ylabel('Jumlah')
  plt.title('Contoh Grouped Bar Plot')

  plt.legend()
  plt.show()

# %%
gambar_barplot()

# %%
#Matlotib Style 

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#Contoh Style 1
style.use('ggplot')
gambar_barplot()

# %%
#Contoh Style 2
style.use('seaborn')
gambar_barplot()

# %%
#Contoh Style 3
style.use('seaborn-paper')
gambar_barplot()

# %%
#Contoh Style 4
style.use('grayscale') #sangat cocok diperuntukan bagi publikasi karya ilmiah yang tidak dicetak secara berwarna
gambar_barplot()
